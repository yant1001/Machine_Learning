# %% [markdown]
# # 1. Text Preprocessing

# %% [markdown]
# ## English Text Preprocessing

# %% [markdown]
# ### Stemming

# %% [markdown]
# ### Lemmatization

# %% [markdown]
# ### Regular Expression

# %% [markdown]
# ### spaCy 활용

# %% [markdown]
# ## 한국어 텍스트 정제

# %% [markdown]
# ### 정규식을 이용한 정제

# %% [markdown]
# ### 맞춤법 정리

# %% [markdown]
# ### 띄어쓰기 정리

# %% [markdown]
# ### Okt를 이용한 한국어 어간 추출

# %% [markdown]
# # 2. Text Tokenization, Integer Encoding

# %% [markdown]
# ## 문장 토큰화

# %% [markdown]
# ### 영어 토큰화

# %% [markdown]
# ### 영어 단어 토큰화

# %% [markdown]
# ### 한국어 단어 토큰화

# %% [markdown]
# ## Keras의 Tokenizer를 이용해서 정수 인코딩 하기

# %% [markdown]
# ### OOV(Out Of Vocabulary) 설정

# %% [markdown]
# ### Padding

# %% [markdown]
# # 3. Text Vectorization

# %% [markdown]
# ## 사이킷런을 이용한 텍스트 벡터화

# %% [markdown]
# ## 20 뉴스그룹 분류

# %% [markdown]
# # 4. Text Mining - WordCloud

# %% [markdown]
# ## 텍스트 마이닝

# %% [markdown]
# ## 스마트폰 리뷰 데이터 살펴보기

# %% [markdown]
# # 5. Text Mining - Topic Modeling

# %% [markdown]
# ## 20 뉴스 그룹 토픽 모델링

# %% [markdown]
# ### LDA 적

# %% [markdown]
# ## 토픽 모델링 시각화

# %% [markdown]
# # 6. Text Mining - Document Clustering, Document Similarity

# %% [markdown]
# ## Tfidf 기반 군집 수행

# %% [markdown]
# ## 군집별 핵심 단어 추출하
